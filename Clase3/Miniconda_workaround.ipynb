# %% [markdown]
# <a href="https://colab.research.google.com/github/cabb99/cdec039/blob/main/Clase3/Miniconda_workaround.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalar Miniconda en google drive

# %%
# !which python
# !python --version
# !pip install pyngrok -q
# Out:
# /usr/local/bin/python
# Python 3.6.9
# ...

# %%
# !echo $PYTHONPATH
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# /env/python
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-py37_4.9.2-Linux-x86_64.sh
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f
# Out:
# PREFIX=/root/miniconda3
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py37h261ae71_2
#     - chardet==3.0.4=py37h06a4308_1003
#     - conda-package-handling==1.7.2=py37h03888b9_0
#     - conda==4.9.2=py37h06a4308_0
#     - cryptography==3.2.1=py37h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py37h06a4308_0
#     - pycosat==0.6.3=py37h27cfd23_0
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
# ...

# %%
# !ln -s /root/miniconda3/bin/conda /usr/local/bin/conda
# !which conda
# !conda --version
# !which python
# !python --version
# Out:
# /usr/local/bin/conda
# conda 4.9.2
# /usr/local/bin/python
# Python 3.6.9

# %%
# !conda update -yq -n base conda
# !which conda
# !conda --version
# !which python
# !python --version
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.8  |       h06a4308_0         121 KB
#     certifi-2020.12.5          |   py37h06a4308_0         141 KB
#     cffi-1.14.4                |   py37h261ae71_0         224 KB
#     cryptography-3.3.1         |   py37h3c74f83_0         565 KB
#     openssl-1.1.1i             |       h27cfd23_0         2.5 MB
#     pip-20.3.1                 |   py37h06a4308_0         1.8 MB
#     pyopenssl-20.0.0           |     pyhd3eb1b0_1          49 KB
#     requests-2.25.0            |     pyhd3eb1b0_0          52 KB
#     setuptools-51.0.0          |   py37h06a4308_2         711 KB
#     tqdm-4.54.1                |     pyhd3eb1b0_0          55 KB
# ...

# %%
# !conda config --add channels conda-forge
# !conda config --add channels omnia
# !conda install -yq jupyter pandas matplotlib numpy scipy scikit-learn MDAnalysis mdtraj prody pyemma MDAnalysisTests mdshare nglview openmm pyngrok jupyterlab
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - jupyter
#     - jupyterlab
#     - matplotlib
#     - mdanalysis
#     - mdanalysistests
#     - mdshare
#     - mdtraj
#     - nglview
#     - numpy
#     - openmm
#     - pandas
#     - prody
#     - pyemma
#     - pyngrok
#     - scikit-learn
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     argon2-cffi-20.1.0         |   py37h4abf009_2          47 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     async_generator-1.10       |             py_0          18 KB  conda-forge
#     attrs-20.3.0               |     pyhd3deb0d_0          41 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
# ...

# %%
! /root/miniconda3/bin/python -m simtk.testInstallation
# Out:
# OpenMM Version: 7.4.2
# Git Revision: dc9d188939ad630d240e89806b185061f7cd661a
#
# There are 4 Platforms available:
#
# 1 Reference - Successfully computed forces
# 2 CPU - Successfully computed forces
# 3 CUDA - Successfully computed forces
# 4 OpenCL - Successfully computed forces
#
# Median difference in forces between platforms:
#
# Reference vs. CPU: 6.30735e-06
# Reference vs. CUDA: 6.72765e-06
# CPU vs. CUDA: 7.82262e-07
# Reference vs. OpenCL: 6.75312e-06
# CPU vs. OpenCL: 8.18349e-07
# CUDA vs. OpenCL: 2.16942e-07
#
# All differences are within tolerance.

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
sys.path.append('/root/miniconda3/lib/python3.7')
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.7/site-packages/',
#  '/root/miniconda3/lib/python3.7']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content/drive/MyDrive/
# git clone https://github.com/cabb99/cdec039.git
# cd cdec039/
# git pull
# Out:
# Already up to date.
# Cloning into 'cdec039'...

# %%
# a fake google.colab library
# !ln -s /usr/local/lib/python3.6/dist-packages/google \
       /root/miniconda3/lib/python3.7/site-packages/google

# start jupyterlab, which now has Python3 = 3.7
# !nohup /root/miniconda3/bin/jupyter-lab --ip=0.0.0.0&
# Out:
# nohup: appending output to 'nohup.out'

# %%
#Necesitamos cambiar de version de python
print(sys.version_info)

# Acceder a traves del link de la izquierda.
# Si les aparece error, cierren la sesion, esperen 1 minuto e intenten de nuevo.

from pyngrok import ngrok
print(ngrok.connect(8888))
# Out:
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)
# NgrokTunnel: "http://cfc31d4dfa71.ngrok.io" -> "http://localhost:8888"

# %%
import time
while True:
  time.sleep(10)
